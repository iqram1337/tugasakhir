# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import obspy

# %%
stream = np.load("NC_MEM_2017100709282692.npz")
stream.files
# Out:
# ['data']

# %%
stream['data'][0]
# Out:
# array([-16.14265082,  -4.12243084,   4.96211532])

# %%
stream['data'][:,0]
# Out:
# array([-16.14265082, -12.14265082, -28.14265082, ...,   3.85734918,
#         -2.14265082,  -8.14265082])

# %%
st1 = stream['data'][:,0]
st2 = stream['data'][:,1]
st3 = stream['data'][:,2]

# %%
plt.figure(figsize=(10, 3))
plt.plot(np.arange(3000), st1)
plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.plot(np.arange(3000), st2)
plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.plot(np.arange(3000), st3)
plt.show()
